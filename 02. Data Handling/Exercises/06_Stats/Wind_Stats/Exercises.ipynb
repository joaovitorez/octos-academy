# %% [markdown]
# # Wind Statistics

# %% [markdown]
# ### Introduction:
#
# The data have been modified to contain some missing values, identified by NaN.
# Using pandas should make this exercise
# easier, in particular for the bonus question.
#
# You should be able to perform all of these operations without using
# a for loop or other looping construct.
#
#
# 1. The data in 'wind.data' has the following format:

# %%
"""
Yr Mo Dy   RPT   VAL   ROS   KIL   SHA   BIR   DUB   CLA   MUL   CLO   BEL   MAL
61  1  1 15.04 14.96 13.17  9.29   NaN  9.87 13.67 10.25 10.83 12.58 18.50 15.04
61  1  2 14.71   NaN 10.83  6.50 12.62  7.67 11.50 10.04  9.79  9.67 17.54 13.83
61  1  3 18.50 16.88 12.33 10.13 11.17  6.17 11.25   NaN  8.50  7.67 12.75 12.71
"""
# Out:
# '\nYr Mo Dy   RPT   VAL   ROS   KIL   SHA   BIR   DUB   CLA   MUL   CLO   BEL   MAL\n61  1  1 15.04 14.96 13.17  9.29   NaN  9.87 13.67 10.25 10.83 12.58 18.50 15.04\n61  1  2 14.71   NaN 10.83  6.50 12.62  7.67 11.50 10.04  9.79  9.67 17.54 13.83\n61  1  3 18.50 16.88 12.33 10.13 11.17  6.17 11.25   NaN  8.50  7.67 12.75 12.71\n'

# %% [markdown]
#    The first three columns are year, month and day.  The
#    remaining 12 columns are average windspeeds in knots at 12
#    locations in Ireland on that day.
#
#    More information about the dataset go [here](wind.desc).

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/Wind_Stats/wind.data)

# %% [markdown]
# ### Step 3. Assign it to a variable called data and replace the first 3 columns by a proper datetime index.

# %%
# O separador do tipo '\s+' serve para quaisquer espaços entre os dados

data = pd.read_csv("https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/Wind_Stats/wind.data", 
                   sep='\s+', parse_dates = [[0,1,2]])
data
# Out:
#        Yr_Mo_Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0    2061-01-01  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1    2061-01-02  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2    2061-01-03  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3    2061-01-04  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4    2061-01-05  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
# 6569 1978-12-27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59
# 6570 1978-12-28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25
# 6571 1978-12-29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46
# 6572 1978-12-30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87
# 6573 1978-12-31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL
# 0     10.83  12.58  18.50  15.04
# 1      9.79   9.67  17.54  13.83
# ...

# %% [markdown]
# ### Step 4. Year 2061? Do we really have data from this year? Create a function to fix it and apply it.

# %%
#Criar uma função para consertar o ano 

#Recebe a coluna do dataframe com tipo datetime
import datetime
def conserta_data(series):
    
    #Acessa o ano da coluna e atualiza conforme alterações
    ano_correto = series.year-100 if series.year >= 2000 else series.year
    
    #Retorna para o series um novo datetime, com mesmo mes e dia, porem ano certo
    return datetime.date(ano_correto, series.month, series.day)
    
data.Yr_Mo_Dy = data.Yr_Mo_Dy.apply(conserta_data)
data
# Out:
#         Yr_Mo_Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0     1961-01-01  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1     1961-01-02  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2     1961-01-03  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3     1961-01-04  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4     1961-01-05  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# ...          ...    ...    ...    ...    ...    ...    ...    ...    ...
# 6569  1978-12-27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59
# 6570  1978-12-28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25
# 6571  1978-12-29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46
# 6572  1978-12-30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87
# 6573  1978-12-31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL
# 0     10.83  12.58  18.50  15.04
# ...

# %% [markdown]
# ### Step 5. Set the right dates as the index. Pay attention at the data type, it should be datetime64[ns].

# %%
data.set_index('Yr_Mo_Dy', inplace=True)
data.index = pd.to_datetime(data.index)
data
# Out:
#               RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA    MUL  \
# Yr_Mo_Dy
# 1961-01-01  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25  10.83
# 1961-01-02  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04   9.79
# 1961-01-03  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN   8.50
# 1961-01-04  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79   5.83
# 1961-01-05  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54  10.92
# ...           ...    ...    ...    ...    ...    ...    ...    ...    ...
# 1978-12-27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59  14.04
# 1978-12-28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25  15.25
# 1978-12-29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46  14.50
# 1978-12-30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87  12.46
# 1978-12-31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63  11.58
#
#               CLO    BEL    MAL
# Yr_Mo_Dy
# ...

# %% [markdown]
# ### Step 6. Compute how many values are missing for each location over the entire record.
# #### They should be ignored in all calculations below.

# %%
data.info() #Só conta quantos não são missing
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6574 entries, 1961-01-01 to 1978-12-31
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RPT     6568 non-null   float64
#  1   VAL     6571 non-null   float64
#  2   ROS     6572 non-null   float64
#  3   KIL     6569 non-null   float64
#  4   SHA     6572 non-null   float64
#  5   BIR     6574 non-null   float64
#  6   DUB     6571 non-null   float64
#  7   CLA     6572 non-null   float64
#  8   MUL     6571 non-null   float64
#  9   CLO     6573 non-null   float64
#  10  BEL     6574 non-null   float64
#  11  MAL     6570 non-null   float64
# dtypes: float64(12)
# memory usage: 667.7 KB

# %%
data.isna().sum()
# Out:
# RPT    6
# VAL    3
# ROS    2
# KIL    5
# SHA    2
# BIR    0
# DUB    3
# CLA    2
# MUL    3
# CLO    1
# BEL    0
# MAL    4
# dtype: int64

# %% [markdown]
# ### Step 7. Compute how many non-missing values there are in total.

# %%
data.isna().sum().sum()
# Out:
# 31

# %% [markdown]
# ### Step 8. Calculate the mean windspeeds of the windspeeds over all the locations and all the times.
# #### A single number for the entire dataset.

# %%
#Calcular a média de cada coluna e depois a média entre as colunas
data.mean().mean()
# Out:
# 10.227982360836924

# %% [markdown]
# ### Step 9. Create a DataFrame called loc_stats and calculate the min, max and mean windspeeds and standard deviations of the windspeeds at each location over all the days
#
# #### A different set of numbers for each location.

# %%
loc_stats = pd.DataFrame(data.agg(['min','max','mean']))
loc_stats
# Out:
#             RPT        VAL        ROS        KIL        SHA        BIR  \
# min    0.670000   0.210000   1.500000   0.000000   0.130000   0.000000
# max   35.800000  33.370000  33.840000  28.460000  37.540000  26.160000
# mean  12.362987  10.644314  11.660526   6.306468  10.455834   7.092254
#
#             DUB        CLA       MUL        CLO        BEL        MAL
# min    0.000000   0.000000   0.00000   0.040000   0.130000   0.670000
# max   30.370000  31.080000  25.88000  28.210000  42.380000  42.540000
# mean   9.797343   8.495053   8.49359   8.707332  13.121007  15.599079

# %% [markdown]
# ### Step 10. Create a DataFrame called day_stats and calculate the min, max and mean windspeed and standard deviations of the windspeeds across all the locations at each day.
#
# #### A different set of numbers for each day.

# %%
day_stats = pd.DataFrame(data.agg(['min','max','mean'], axis=1))
day_stats
# Out:
#              min    max       mean
# 1961-01-01  9.29  18.50  13.018182
# 1961-01-02  6.50  17.54  11.336364
# 1961-01-03  6.17  18.50  11.641818
# 1961-01-04  1.79  11.75   6.619167
# 1961-01-05  6.17  13.33  10.630000
# ...          ...    ...        ...
# 1978-12-27  8.08  40.08  16.708333
# 1978-12-28  5.00  41.46  15.150000
# 1978-12-29  8.71  29.58  14.890000
# 1978-12-30  9.13  28.79  15.367500
# 1978-12-31  9.59  27.29  15.402500
#
# [6574 rows x 3 columns]

# %% [markdown]
# ### Step 11. Find the average windspeed in January for each location.
# #### Treat January 1961 and January 1962 both as January.

# %%
#Volto para o index padrão
provisorio = data.reset_index()
provisorio

#Coloco a coluna das datas para datetime
provisorio.Yr_Mo_Dy = pd.to_datetime(provisorio.Yr_Mo_Dy)

#Formata a coluna para '%B' que considera apenas o mês por extenso do datetime, usando strftime
#Agrupo as colunas por mês, calcula a média e retorna apenas o mês de Janeiro
provisorio.groupby(provisorio.Yr_Mo_Dy.dt.strftime('%B')).mean().loc[['January']]
# Out:
#                 RPT       VAL        ROS       KIL        SHA       BIR  \
# Yr_Mo_Dy
# January   14.847325  12.91456  13.299624  7.199498  11.667734  8.054839
#
#                 DUB       CLA       MUL        CLO       BEL        MAL
# Yr_Mo_Dy
# January   11.819355  9.512047  9.543208  10.053566  14.55052  18.028763

# %% [markdown]
# ### Step 12. Downsample the record to a yearly frequency for each location.

# %%
data.resample('AS').sum()
# Out:
#                 RPT      VAL      ROS      KIL      SHA      BIR      DUB  \
# Yr_Mo_Dy
# 1961-01-01  4427.85  3747.35  4124.54  2511.92  3950.08  2821.35  3523.68
# 1962-01-01  4457.88  3690.31  4282.44  2533.60  3890.14  2698.47  4022.56
# 1963-01-01  4676.91  3955.50  4577.52  2675.47  4279.30  3078.67  4042.63
# 1964-01-01  4525.10  3996.78  4430.20  2484.33  4192.34  2770.94  3754.85
# 1965-01-01  4544.75  4042.57  4324.80  2503.34  4024.05  2729.51  3875.83
